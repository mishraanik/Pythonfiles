# %% [markdown]
# START
# #Aniket Mishra

# %%
a =10

# %%
a #jupyter output
# Out:
# 10

# %%
print(a)  #console output
# Out:
# 10

# %%
#variable declaration

a=10  #integer type
b=5.1 #float value
c="hey"  #string type 

#in python we need not to tell python that what sort of datatypes we are using

# %%
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
#arithematic operation on python

a=10
b=8
c=7

# %%
print(a+b)
print(a-b)
print(a*b)
print(a^b)
print(a^a^a)
print(a^b^a)
# Out:
# 18
# 2
# 80
# 2
# 10
# 8

# %%
print(a//b) # it is just integer division
print(10//3) #float division not a integer division it won"t give value like 3.3333 instead gives 3 only
# Out:
# 1
# 3

# %%
print(2**3) #2 is raised to power 2 by itself 3 times
print(10%5)
print(10%4) #remainder
# Out:
# 8
# 0
# 2

# %%
print(f"this is value of a = {a}" )
print(a,b,(a+b),(a-b),(a//b)) #print more than one operations by seperating them by commas

print("this is value of a = {a}" ) #checking out the difference
# Out:
# this is value of a = 10
# 10 8 18 2 1
# this is value of a = {a}

# %% [markdown]
# #LOGICAL OPERATIONS
