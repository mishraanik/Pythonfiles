# %% [markdown]
# #LOGICAL Operator

# %%
rain = False
outside = True

playing = rain and outside
roaming = not rain and outside
broking = rain or outside
choking = not rain or outside

# %%
print(playing)
print(roaming)
print(broking)
print(choking)
# Out:
# False
# True
# True
# True

# %% [markdown]
# #If_else

# %%
a = 5
print(" input any number")
guess = int(input())

if guess % 2 == 0 :
    print("Number is even")
    
    print("Please again enter the number you wish to check")
    guess = int(input())
    if guess // 2 == 0 :
        print("Number is even")
    
    else:
        print("Naah again its odd you know")
else :
    print("Number is odd")
# Out:
#  input any number
# 79
# Number is odd

# %%
# to check whether a number is divided by 3 remainder comes out to be 0 , 1, 2

print("Enter any number you wish to check")
guess = int(input())

if guess % 3 == 0 or guess %3 ==1 or guess % 3 == 2 :
    print("Number is divided by 3 remainder comes out to be 0 , 1, 2")
    
else :
    print("Number is fully divided by 3")
# Out:
# Enter any number you wish to check
# 665
# Number is divided by 3 remainder comes out to be 0 , 1, 2

# %%
# to check what comes remainder when a number is divided by 3 

a = 18

print("enter a number you wish to check")
guess = int(input())

if guess % 3 == 0:
    print("Fully divided ")
    print("ZERO")
    
elif guess % 3 == 1:
    print("Reaminder comes out to be ONE")
    
else :
    print("Output comes out to be two")
